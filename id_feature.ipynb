# %%
import pandas as pd
import numpy as np

train = pd.read_csv("Train.csv")

train.head()
# Out:
#     ID_Zindi    Date    ID        LAT        LON  Precipitation  LST  \
# 0  ID_ENTGC7  1/1/19  PD01  45.601585  11.903551       0.000000  NaN
# 1  ID_8JCCXC  1/1/19  PD04  45.371005  11.840830       3.047342  NaN
# 2  ID_V3136Z  1/1/19  RO01  45.045825  12.060869       0.000000  NaN
# 3  ID_KRVZDJ  1/1/19  RO02  45.104075  11.553241       1.200467  NaN
# 4  ID_PR351A  1/1/19  RO03  45.038758  11.790152       1.274564  NaN
#
#         AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# 0  0.230527       0.559117   0.000024   0.000117       NaN
# 1 -0.074006       0.869309   0.000024   0.000127       NaN
# 2  0.024470       0.674160   0.000024   0.000086       NaN
# 3 -0.010442       0.920054   0.000024   0.000124       NaN
# 4 -0.176178       0.747464   0.000024   0.000116       NaN
#
#    TropopausePressure  GT_NO2
# 0         14440.82126    31.0
# 1         14441.79815    42.0
# 2         14437.38294    31.0
# 3         14440.83831    30.0
# 4         14438.79037    58.0

# %%
train = train.drop(['ID_Zindi'], axis = 1)

# %%
train
# Out:
#            Date     ID        LAT        LON  Precipitation     LST       AAI  \
# 0        1/1/19   PD01  45.601585  11.903551       0.000000     NaN  0.230527
# 1        1/1/19   PD04  45.371005  11.840830       3.047342     NaN -0.074006
# 2        1/1/19   RO01  45.045825  12.060869       0.000000     NaN  0.024470
# 3        1/1/19   RO02  45.104075  11.553241       1.200467     NaN -0.010442
# 4        1/1/19   RO03  45.038758  11.790152       1.274564     NaN -0.176178
# ...         ...    ...        ...        ...            ...     ...       ...
# 86579  31-12-21  X9897  45.498227   9.556232       0.000000     NaN -0.434350
# 86580  31-12-21  X9928  45.142541  10.043836       0.000000     NaN       NaN
# 86581  31-12-21  X9969  45.842207   9.351658       0.000000  284.98 -0.157753
# 86582  31-12-21  X9993  45.113503   8.874065       0.000000     NaN -0.798636
# 86583  31-12-21  X9999  45.526473   9.515980       0.000000     NaN -0.434482
#
# ...

# %%
train = train.dropna(subset=['GT_NO2'])

# %%
train
# Out:
#            Date     ID        LAT        LON  Precipitation     LST       AAI  \
# 0        1/1/19   PD01  45.601585  11.903551       0.000000     NaN  0.230527
# 1        1/1/19   PD04  45.371005  11.840830       3.047342     NaN -0.074006
# 2        1/1/19   RO01  45.045825  12.060869       0.000000     NaN  0.024470
# 3        1/1/19   RO02  45.104075  11.553241       1.200467     NaN -0.010442
# 4        1/1/19   RO03  45.038758  11.790152       1.274564     NaN -0.176178
# ...         ...    ...        ...        ...            ...     ...       ...
# 86579  31-12-21  X9897  45.498227   9.556232       0.000000     NaN -0.434350
# 86580  31-12-21  X9928  45.142541  10.043836       0.000000     NaN       NaN
# 86581  31-12-21  X9969  45.842207   9.351658       0.000000  284.98 -0.157753
# 86582  31-12-21  X9993  45.113503   8.874065       0.000000     NaN -0.798636
# 86583  31-12-21  X9999  45.526473   9.515980       0.000000     NaN -0.434482
#
# ...

# %%
np.unique(train['ID'])
# Out:
# array(['PD01', 'PD04', 'RO01', 'RO02', 'RO03', 'TV01', 'TV02', 'VE01',
#        'VE02', 'VE03', 'VI02', 'VI03', 'VI04', 'VR02', 'VR04', 'X10019',
#        'X10038', 'X10079', 'X10097', 'X10167', 'X10279', 'X10326',
#        'X10331', 'X10452', 'X10458', 'X10507', 'X12017', 'X17286',
#        'X20034', 'X20491', 'X20495', 'X30163', 'X5504', 'X5507', 'X5517',
#        'X5520', 'X5531', 'X5532', 'X5534', 'X5542', 'X5545', 'X5547',
#        'X5548', 'X5549', 'X5554', 'X5557', 'X5568', 'X5579', 'X5586',
#        'X5587', 'X5591', 'X5595', 'X5598', 'X5599', 'X5601', 'X5603',
#        'X5607', 'X5609', 'X5610', 'X5611', 'X5950', 'X5958', 'X5965',
#        'X6685', 'X6781', 'X6813', 'X6826', 'X6859', 'X6871', 'X6880',
#        'X9802', 'X9852', 'X9857', 'X9877', 'X9897', 'X9928', 'X9969',
#        'X9993', 'X9999'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(train['ID'])
le.classes_
# Out:
# array(['PD01', 'PD04', 'RO01', 'RO02', 'RO03', 'TV01', 'TV02', 'VE01',
#        'VE02', 'VE03', 'VI02', 'VI03', 'VI04', 'VR02', 'VR04', 'X10019',
#        'X10038', 'X10079', 'X10097', 'X10167', 'X10279', 'X10326',
#        'X10331', 'X10452', 'X10458', 'X10507', 'X12017', 'X17286',
#        'X20034', 'X20491', 'X20495', 'X30163', 'X5504', 'X5507', 'X5517',
#        'X5520', 'X5531', 'X5532', 'X5534', 'X5542', 'X5545', 'X5547',
#        'X5548', 'X5549', 'X5554', 'X5557', 'X5568', 'X5579', 'X5586',
#        'X5587', 'X5591', 'X5595', 'X5598', 'X5599', 'X5601', 'X5603',
#        'X5607', 'X5609', 'X5610', 'X5611', 'X5950', 'X5958', 'X5965',
#        'X6685', 'X6781', 'X6813', 'X6826', 'X6859', 'X6871', 'X6880',
#        'X9802', 'X9852', 'X9857', 'X9877', 'X9897', 'X9928', 'X9969',
#        'X9993', 'X9999'], dtype=object)

# %%
train['ID_label'] = le.transform(train['ID'])
# Out:
# /tmp/ipykernel_19672/2812803463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['ID_label'] = le.transform(train['ID'])

# %%
train
# Out:
#            Date     ID        LAT        LON  Precipitation     LST       AAI  \
# 0        1/1/19   PD01  45.601585  11.903551       0.000000     NaN  0.230527
# 1        1/1/19   PD04  45.371005  11.840830       3.047342     NaN -0.074006
# 2        1/1/19   RO01  45.045825  12.060869       0.000000     NaN  0.024470
# 3        1/1/19   RO02  45.104075  11.553241       1.200467     NaN -0.010442
# 4        1/1/19   RO03  45.038758  11.790152       1.274564     NaN -0.176178
# ...         ...    ...        ...        ...            ...     ...       ...
# 86579  31-12-21  X9897  45.498227   9.556232       0.000000     NaN -0.434350
# 86580  31-12-21  X9928  45.142541  10.043836       0.000000     NaN       NaN
# 86581  31-12-21  X9969  45.842207   9.351658       0.000000  284.98 -0.157753
# 86582  31-12-21  X9993  45.113503   8.874065       0.000000     NaN -0.798636
# 86583  31-12-21  X9999  45.526473   9.515980       0.000000     NaN -0.434482
#
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_data = train.select_dtypes(include=numerics)

numerical_data.corr()
# Out:
#                          LAT       LON  Precipitation       LST       AAI  \
# LAT                 1.000000 -0.022141       0.036309 -0.021704 -0.010530
# LON                -0.022141  1.000000      -0.027969 -0.040191  0.018136
# Precipitation       0.036309 -0.027969       1.000000  0.094024  0.010258
# LST                -0.021704 -0.040191       0.094024  1.000000 -0.190705
# AAI                -0.010530  0.018136       0.010258 -0.190705  1.000000
# CloudFraction       0.034476  0.032806       0.256010 -0.127959  0.237155
# NO2_strat          -0.015882  0.017980       0.091035  0.823847 -0.168853
# NO2_total           0.094768 -0.169743      -0.054224 -0.441185  0.146879
# NO2_trop            0.183185 -0.170945      -0.099535 -0.530231  0.194345
# TropopausePressure -0.002599 -0.001950       0.029750 -0.346425  0.019963
# GT_NO2              0.175449 -0.102680      -0.032344 -0.519646  0.168820
# ID_label           -0.150490 -0.547540       0.009946 -0.005931 -0.041254
#
# ...

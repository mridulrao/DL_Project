# %%
import pandas as pd
df = pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#     ID_Zindi    Date    ID        LAT        LON  Precipitation  LST  \
# 0  ID_ENTGC7  1/1/19  PD01  45.601585  11.903551       0.000000  NaN
# 1  ID_8JCCXC  1/1/19  PD04  45.371005  11.840830       3.047342  NaN
# 2  ID_V3136Z  1/1/19  RO01  45.045825  12.060869       0.000000  NaN
# 3  ID_KRVZDJ  1/1/19  RO02  45.104075  11.553241       1.200467  NaN
# 4  ID_PR351A  1/1/19  RO03  45.038758  11.790152       1.274564  NaN
#
#         AAI  CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# 0  0.230527       0.559117   0.000024   0.000117       NaN
# 1 -0.074006       0.869309   0.000024   0.000127       NaN
# 2  0.024470       0.674160   0.000024   0.000086       NaN
# 3 -0.010442       0.920054   0.000024   0.000124       NaN
# 4 -0.176178       0.747464   0.000024   0.000116       NaN
#
#    TropopausePressure  GT_NO2
# 0         14440.82126    31.0
# 1         14441.79815    42.0
# 2         14437.38294    31.0
# 3         14440.83831    30.0
# 4         14438.79037    58.0

# %%
df.describe()
# Out:
#                 LAT           LON  Precipitation           LST           AAI  \
# count  86584.000000  86584.000000   86584.000000  46798.000000  73709.000000
# mean      45.421456     10.014272       2.585528    299.268841     -1.274999
# std        0.225409      1.056637       7.617394     10.927167      0.693003
# min       44.924694      8.736497       0.000000    253.200000     -5.196266
# 25%       45.249544      9.195325       0.000000    290.920000     -1.749425
# 50%       45.478996      9.611738       0.000000    300.760000     -1.349746
# 75%       45.601232     10.683357       0.000000    307.940000     -0.878857
# max       45.889734     12.590682     135.396805    327.840000      2.143020
#
#        CloudFraction     NO2_strat     NO2_total      NO2_trop  \
# count   73709.000000  73709.000000  73709.000000  51111.000000
# mean        0.200606      0.000045      0.000156      0.000105
# std         0.259607      0.000012      0.000103      0.000092
# min         0.000000      0.000013     -0.000012     -0.000025
# 25%         0.023900      0.000034      0.000100      0.000047
# 50%         0.078478      0.000047      0.000122      0.000071
# 75%         0.278451      0.000056      0.000173      0.000129
# max         1.000000      0.000073      0.002047      0.001097
#
#        TropopausePressure        GT_NO2
# count        73709.000000  82051.000000
# mean         16655.112392     24.535051
# std           3000.748790     17.108838
# min           8614.349685      0.000000
# 25%          14432.114060     11.875000
# 50%          16711.190570     20.000000
# 75%          19252.648570     33.050000
# max          24449.007150    188.233333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86584 entries, 0 to 86583
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Zindi            86584 non-null  object
#  1   Date                86584 non-null  object
#  2   ID                  86584 non-null  object
#  3   LAT                 86584 non-null  float64
#  4   LON                 86584 non-null  float64
#  5   Precipitation       86584 non-null  float64
#  6   LST                 46798 non-null  float64
#  7   AAI                 73709 non-null  float64
#  8   CloudFraction       73709 non-null  float64
#  9   NO2_strat           73709 non-null  float64
#  10  NO2_total           73709 non-null  float64
#  11  NO2_trop            51111 non-null  float64
#  12  TropopausePressure  73709 non-null  float64
#  13  GT_NO2              82051 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 9.2+ MB

# %%
df_num = df.select_dtypes(include = ['float64'])

# %%
df_num
# Out:
#              LAT        LON  Precipitation     LST       AAI  CloudFraction  \
# 0      45.601585  11.903551       0.000000     NaN  0.230527       0.559117
# 1      45.371005  11.840830       3.047342     NaN -0.074006       0.869309
# 2      45.045825  12.060869       0.000000     NaN  0.024470       0.674160
# 3      45.104075  11.553241       1.200467     NaN -0.010442       0.920054
# 4      45.038758  11.790152       1.274564     NaN -0.176178       0.747464
# ...          ...        ...            ...     ...       ...            ...
# 86579  45.498227   9.556232       0.000000     NaN -0.434350       0.250490
# 86580  45.142541  10.043836       0.000000     NaN       NaN            NaN
# 86581  45.842207   9.351658       0.000000  284.98 -0.157753       0.000000
# 86582  45.113503   8.874065       0.000000     NaN -0.798636       0.399524
# 86583  45.526473   9.515980       0.000000     NaN -0.434482       0.250530
#
#        NO2_strat  NO2_total  NO2_trop  TropopausePressure  GT_NO2
# 0       0.000024   0.000117       NaN         14440.82126  31.000
# 1       0.000024   0.000127       NaN         14441.79815  42.000
# 2       0.000024   0.000086       NaN         14437.38294  31.000
# 3       0.000024   0.000124       NaN         14440.83831  30.000
# 4       0.000024   0.000116       NaN         14438.79037  58.000
# ...          ...        ...       ...                 ...     ...
# 86579   0.000032   0.000643       NaN         13063.79770  39.750
# 86580        NaN        NaN       NaN                 NaN  30.125
# 86581   0.000031   0.000153  0.000122         13050.16499  28.325
# 86582   0.000031   0.000717       NaN         13061.41329  21.250
# 86583   0.000032   0.000643       NaN         13063.79500  40.350
#
# [86584 rows x 11 columns]

# %%
df_num.corr()
# Out:
#                          LAT       LON  Precipitation       LST       AAI  \
# LAT                 1.000000 -0.023466       0.036259 -0.019714 -0.011746
# LON                -0.023466  1.000000      -0.026927 -0.040727  0.016865
# Precipitation       0.036259 -0.026927       1.000000  0.094854  0.010039
# LST                -0.019714 -0.040727       0.094854  1.000000 -0.190327
# AAI                -0.011746  0.016865       0.010039 -0.190327  1.000000
# CloudFraction       0.034848  0.032432       0.255837 -0.123005  0.239349
# NO2_strat          -0.016551  0.017688       0.092666  0.823390 -0.165814
# NO2_total           0.097346 -0.168467      -0.055716 -0.443075  0.143546
# NO2_trop            0.185288 -0.168817      -0.100178 -0.531214  0.190965
# TropopausePressure -0.002258 -0.001186       0.030254 -0.349435  0.021379
# GT_NO2              0.175449 -0.102680      -0.032344 -0.519646  0.168820
#
#                     CloudFraction  NO2_strat  NO2_total  NO2_trop  \
# LAT                      0.034848  -0.016551   0.097346  0.185288
# LON                      0.032432   0.017688  -0.168467 -0.168817
# Precipitation            0.255837   0.092666  -0.055716 -0.100178
# LST                     -0.123005   0.823390  -0.443075 -0.531214
# AAI                      0.239349  -0.165814   0.143546  0.190965
# CloudFraction            1.000000  -0.069296   0.045238  0.040644
# NO2_strat               -0.069296   1.000000  -0.436923 -0.563020
# NO2_total                0.045238  -0.436923   1.000000  0.986797
# NO2_trop                 0.040644  -0.563020   0.986797  1.000000
# TropopausePressure       0.198747  -0.081240   0.025244  0.065160
# GT_NO2                   0.011319  -0.558997   0.596019  0.726991
#
#                     TropopausePressure    GT_NO2
# LAT                          -0.002258  0.175449
# LON                          -0.001186 -0.102680
# Precipitation                 0.030254 -0.032344
# LST                          -0.349435 -0.519646
# AAI                           0.021379  0.168820
# CloudFraction                 0.198747  0.011319
# NO2_strat                    -0.081240 -0.558997
# NO2_total                     0.025244  0.596019
# NO2_trop                      0.065160  0.726991
# TropopausePressure            1.000000  0.048618
# GT_NO2                        0.048618  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df_num.corr(), annot=True, cmap='coolwarm', fmt=".1f")
plt.show()

# %%
pd.plotting.scatter_matrix(df, alpha=0.3,figsize=(15,8),diagonal='kde' )
plt.tight_layout()
